# %% [markdown]
# # Modules!
#
# 1. Challenge question
# 2. What are modules?
# 3. What is `import`, and how does it work?
# 4. Developing a module
# 5. Python's standard library
# 6. Modules vs. packages
# 7. PyPI
# 8. `pip` and installing packages from PyPI

# %%
# !whoami
# Out:
# reuven

# %% [markdown]
# # Python Skills Challenge: Functions
#
# In this challenge, you are to write a function `count_ips`. The function will take a single argument, a string naming a logfile from a Web server.  The function will return a Python dict, in which the keys are IP addresses from the file, and the values represent the number of times each IP address made a request from the site.
#
# Here are the first few lines from the sort of logfile the function should expect:
#
# ```
# 67.218.116.165 - - [30/Jan/2010:00:03:18 +0200] "GET /robots.txt HTTP/1.0" 200 99 "-" "Mozilla/5.0 (Twiceler-0.9 http://www.cuil.com/twiceler/robot.html)"
# 66.249.71.65 - - [30/Jan/2010:00:12:06 +0200] "GET /browse/one_node/1557 HTTP/1.1" 200 39208 "-" "Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"
# 65.55.106.183 - - [30/Jan/2010:01:29:23 +0200] "GET /robots.txt HTTP/1.1" 200 99 "-" "msnbot/2.0b (+http://search.msn.com/msnbot.htm)"
# 65.55.106.183 - - [30/Jan/2010:01:30:06 +0200] "GET /browse/one_model/2162 HTTP/1.1" 200 2181 "-" "msnbot/2.0b (+http://search.msn.com/msnbot.htm)"
# 66.249.71.65 - - [30/Jan/2010:02:07:14 +0200] "GET /browse/browse_applet_tab/2593 HTTP/1.1" 200 10305 "-" "Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"
# ```
#
# Notice that each line of the file starts with an IP address, and then has (among other things) the timestamp at which the request was made, the actual request, and an indication of what browser was used to make the request.
#
# If the file is empty, then the returned dictionary should be empty.
#
# This Katacoda challenge system will test your function against a file, `logfile.txt`, that is in the current `/root` directory. When the function returns the correct values, you will see an indication of this.
#
# Good luck!

# %%
# set the filename we're reading from
# (same as logfile.txt in the challenge -- this is the name on my system and GitHub)
filename = 'mini-access-log.txt'  

# define the function 
def count_ips(infilename):

    # setup
    output = {}
    
    # processing
    for one_line in open(infilename):
        print(len(one_line), end=' ')   # don't go down one line after each print
    
    # output
    return output

# run the function
count_ips(filename)
# Out:
# 155 172 135 148 181 187 159 172 178 170 172 135 148 178 189 177 177 178 177 177 135 139 178 178 177 155 169 159 150 164 177 176 171 171 172 171 134 127 178 171 172 191 191 176 178 134 146 178 134 176 163 178 198 176 190 187 183 193 183 199 196 187 195 184 184 187 196 190 192 190 195 196 192 192 197 190 195 177 178 135 148 178 176 166 177 320 320 176 178 176 156 176 168 177 177 177 135 145 177 173 176 133 178 134 147 174 155 172 228 176 177 125 176 159 176 166 177 176 152 134 148 154 147 139 148 156 156 156 156 156 156 150 149 155 156 156 156 155 151 142 178 176 156 177 179 171 180 179 125 177 180 178 178 178 177 177 179 172 176 177 176 177 178 177 181 176 178 178 176 171 178 240 236 249 252 284 282 274 272 272 277 274 277 278 279 178 134 125 139 177 176 177 177 179 178 134 141 176 178 178 178 176 178 178 172 171
# {}

# %%
# set the filename we're reading from
# (same as logfile.txt in the challenge -- this is the name on my system and GitHub)
filename = 'mini-access-log.txt'  

# define the function 
def count_ips(infilename):

    # setup
    output = {}
    
    # processing
    for one_line in open(infilename):
        print(one_line.split()[0])  # split without an argument == split on whitespace of any length
    
    # output
    return output

# run the function
count_ips(filename)
# Out:
# 67.218.116.165
# 66.249.71.65
# 65.55.106.183
# 65.55.106.183
# 66.249.71.65
# 66.249.71.65
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 65.55.106.131
# 65.55.106.131
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 65.55.106.186
# 65.55.106.186
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 74.52.245.146
# 74.52.245.146
# 66.249.65.43
# 66.249.65.43
# 66.249.65.43
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 65.55.207.25
# 65.55.207.25
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 65.55.207.94
# 65.55.207.94
# 66.249.65.12
# 65.55.207.71
# 66.249.65.12
# 66.249.65.12
# 66.249.65.12
# 98.242.170.241
# 66.249.65.38
# 66.249.65.38
# 66.249.65.38
# 66.249.65.38
# 66.249.65.38
# 66.249.65.38
# 66.249.65.38
# 66.249.65.38
# 66.249.65.38
# 66.249.65.38
# 66.249.65.38
# 66.249.65.38
# ...

# %%
from friendly import jupyter
# Out:
# friendly_traceback 0.4.5; friendly 0.4.6.
# Type 'Friendly' for information.

# %%
# set the filename we're reading from
# (same as logfile.txt in the challenge -- this is the name on my system and GitHub)
filename = 'mini-access-log.txt'  

# define the function 
def count_ips(infilename):

    # setup
    output = {}
    
    # processing
    for one_line in open(infilename):
        ip_address = one_line.split()[0]
        
        if ip_address in output:   # have we seen this key (ip_address) before?
            output[ip_address] += 1
        else:                      # first time seeing this IP address? set it to 1
            output[ip_address] = 1  
    
    # output
    return output

# run the function
count_ips(filename)
# Out:
# {
# │   '67.218.116.165': 2,
# │   '66.249.71.65': 3,
# │   '65.55.106.183': 2,
# │   '66.249.65.12': 32,
# │   '65.55.106.131': 2,
# │   '65.55.106.186': 2,
# │   '74.52.245.146': 2,
# │   '66.249.65.43': 3,
# │   '65.55.207.25': 2,
# │   '65.55.207.94': 2,
# │   '65.55.207.71': 1,
# │   '98.242.170.241': 1,
# │   '66.249.65.38': 100,
# │   '65.55.207.126': 2,
# │   '82.34.9.20': 2,
# │   '65.55.106.155': 2,
# │   '65.55.207.77': 2,
# │   '208.80.193.28': 1,
# │   '89.248.172.58': 22,
# │   '67.195.112.35': 16,
# │   '65.55.207.50': 3,
# │   '65.55.215.75': 2
# }

# %%
d = {}   # empty dictionary

d['a'] = 5    # sets the new key-value pair, 'a':5
d['a'] += 6   # updates the value for 'a' to be 5+6 == 11

d
# Out:
# {'a': 11}

# %%
# try it with a key that doesn't exist

d['b'] += 7    # add 7 to the current value associated with 'b'.... but 'b' isn't a key in d!
# Out:
# KeyError: 'b'
#         <button id='friendly-tb-btn-show2' onclick='friendly_toggle_more2()' style=''>
#         More ...
#         </button>
#         <script> function friendly_toggle_more2(){
#         var btn = document.getElementById('friendly-tb-btn-show2');
#         var btn_what = document.getElementById('friendly-tb-btn-show-what2');
#         var btn_where = document.getElementById('friendly-tb-btn-show-where2');
#         var btn_why = document.getElementById('friendly-tb-btn-show-why2');
#         var message = document.getElementById('friendly-message2');
#         var friendly_tb_content = document.getElementById('friendly-tb-friendly_tb-content2');
#         var what_content = document.getElementById('friendly-tb-what-content2');
#         var why_content = document.getElementById('friendly-tb-why-content2');
#         var where_content = document.getElementById('friendly-tb-where-content2');
#
#         if (btn_what.style.display == 'none'){
# ...

# %%
# same thing, but using dict.get

# set the filename we're reading from
# (same as logfile.txt in the challenge -- this is the name on my system and GitHub)
filename = 'mini-access-log.txt'  

# define the function 
def count_ips(infilename):

    # setup
    output = {}
    
    # processing
    for one_line in open(infilename):
        ip_address = one_line.split()[0]
        
        # add 1 to either (a) the current value associated with ip_address, if it exists, or
        # (b) 0, if ip_address is *not* a key in output
        output[ip_address] = output.get(ip_address, 0) + 1
    
    # output
    return output

# run the function
count_ips(filename)
# Out:
# {
# │   '67.218.116.165': 2,
# │   '66.249.71.65': 3,
# │   '65.55.106.183': 2,
# │   '66.249.65.12': 32,
# │   '65.55.106.131': 2,
# │   '65.55.106.186': 2,
# │   '74.52.245.146': 2,
# │   '66.249.65.43': 3,
# │   '65.55.207.25': 2,
# │   '65.55.207.94': 2,
# │   '65.55.207.71': 1,
# │   '98.242.170.241': 1,
# │   '66.249.65.38': 100,
# │   '65.55.207.126': 2,
# │   '82.34.9.20': 2,
# │   '65.55.106.155': 2,
# │   '65.55.207.77': 2,
# │   '208.80.193.28': 1,
# │   '89.248.172.58': 22,
# │   '67.195.112.35': 16,
# │   '65.55.207.50': 3,
# │   '65.55.215.75': 2
# }

# %%
# count_ips(filename) returns a dict
# we can run .items() on a dict
# it gives us back the keys and values

for key, value in count_ips(filename).items():
    print(f'{key}: {value}')
# Out:
# 67.218.116.165: 2
# 66.249.71.65: 3
# 65.55.106.183: 2
# 66.249.65.12: 32
# 65.55.106.131: 2
# 65.55.106.186: 2
# 74.52.245.146: 2
# 66.249.65.43: 3
# 65.55.207.25: 2
# 65.55.207.94: 2
# 65.55.207.71: 1
# 98.242.170.241: 1
# 66.249.65.38: 100
# 65.55.207.126: 2
# 82.34.9.20: 2
# 65.55.106.155: 2
# 65.55.207.77: 2
# 208.80.193.28: 1
# 89.248.172.58: 22
# 67.195.112.35: 16
# 65.55.207.50: 3
# 65.55.215.75: 2

# %% [markdown]
# # How to sort anything (including dicts)
#
# https://ep2020.europython.eu/talks/3dPHGm7-how-to-sort-anything/

# %% [markdown]
# # Modules
#
# Remember the DRY ("Don't repeat yourself") rule?
#
# - If we have several lines in a row that are identical (or nearly identical), we can DRY up our code with a loop.
# - If we have the same code in several places in our program, we can DRY up our code with a function.
# - If we have the same code across several different programs, we can use a "library," or as we call it in Python, a module.
#
# A "library" is a file containing data (variables), classes, and functions that we want to use in multiple programs.
#
# Libraries solve several problems:
# - Yes, they allow us to DRY up our code.
# - They allow us to ignore the implementation details of complex stuff. That way, we can work at a higher level of abstraction.

# %%
import random            # loads the random module in Python
random.randint(0, 100)   # returns a random int from 0 to 100
# Out:
# 90

# %% [markdown]
# # Python modules do two things
#
# 1. They provide us with libraries.
# 2. They provide us with *namespaces*.
#
# Namespaces are sort of like last names (surnames) in the programming world. They allow more than one part of a program to use the same variable names, without having to worry about "namespace collisions."

# %%
random
# Out:
# <module 'random' from '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/random.py'>

# %%
# special Jupyter trick!
# use ?? after a function name to see its source code

random.randrange??

# %% [markdown]
# # What can modules contain?
#
# - Functions
# - Data types (classes)
# - Data

# %%
random.randint(0, 100)
# Out:
# 34

# %%
import os
os.listdir('.')   # return a list of strings (filenames) for the current directory
# Out:
# [
# │   'myconfig.txt',
# │   'myplot.png',
# │   'mini-access-log.txt',
# │   'mysum.py~',
# │   'Office hours, 2021 09Sep 1.ipynb',
# │   '.DS_Store',
# │   'First steps, 2021 08Aug 12.html',
# │   'nums.txt',
# │   'First steps, 2021 08Aug 26.ipynb',
# │   'newwcfile.txt',
# │   'First steps, 2021 08Aug 19.ipynb',
# │   'First steps, 2021 08Aug 19.html',
# │   'shoe-data.txt',
# │   'linux-etc-passwd.txt',
# │   'myfile2.txt',
# │   'README.md',
# │   'wcfile.txt',
# │   '.mypy_cache',
# │   'README.md~',
# │   'profiles_settings.xml',
# │   'exercise-files.zip',
# │   'First steps, 2021 09Sep 09.ipynb',
# │   'mydata.csv',
# │   'myfile.txt',
# │   '.ipynb_checkpoints',
# │   '.git',
# │   'First steps, 2021 08Aug 12.ipynb',
# │   'First steps, 2021 09Sep 2.ipynb',
# │   'output.txt',
# │   'file with spaces in its name.txt',
# │   'mysum.py'
# ]

# %%
# modules can contain classes (new data types)
# example: Counter class
# a version of dictionary whose keys are what we want to count, and whose values are those counts

import collections   # a module
c = collections.Counter('abcaaabaaacaaadefb')  # feed it an iterable, and it'll count each item

# %%
c
# Out:
# Counter({'a': 10, 'b': 3, 'c': 2, 'd': 1, 'e': 1, 'f': 1})

# %%
# modules can also include data

import sys   # the module that contains Python's runtime system
sys.version  # what version of Python are we running?
# Out:
# '3.9.7 (default, Sep  3 2021, 12:37:55) \n[Clang 12.0.5 (clang-1205.0.22.9)]'

# %%
sys.platform   # what operating system are we running on?
# Out:
# 'darwin'

# %% [markdown]
# # Exercise: Guessing game (new and improved)
#
# 1. Use the `random` module to generate a random integer between 0 and 100.  Assign this to `number`.
# 2. Assign `score` to be 0.
# 3. Ask the user, repeatedly, to guess the random number.
# 4. If the user guesses correctly, congratulate them and print their score.
# 5. If the user is wrong, then tell them "too high" or "too low", and add 1 to their score.
# 6. If the user enters a non-numeric value, scold them and try again.
#
# Example:
#
#     Guess the number: 50
#     Too high!
#     Guess the number: 2
#     Too low!
#     Guess the number: I hate this game
#     I hate this game is not numeric, try again
#     Guess this number: 28
#     You got it! Your score is 2.

# %%
import random

score = 0
number = random.randint(0, 100)

while True:
    s = input('Guess the number: ').strip()
    
    if s.isdigit():
        n = int(s)
        
        if n == number:
            print('You got it!')
            break
        elif n < number:
            print('Too low!')
            score += 1
        else:
            print('Too high!')
            score += 1
    else:
        print(f'{s} is not numeric; try again!')
        
print(f'Your score is {score}')
# Out:
# Guess the number: 50
# Too high!
# Guess the number: 40
# Too high!
# Guess the number: 39
# Too high!
# Guess the number: 1
# Too low!
# Guess the number: 5
# Too low!
# Guess the number: 10
# Too high!
# Guess the number: 7
# Too high!
# Guess the number: 5
# Too low!
# Guess the number: 6
# You got it!
# Your score is 8

# %%
import random

def guessing_game():

    score = 0
    number = random.randint(0, 100)

    while True:
        s = input('Guess the number: ').strip()

        if s.isdigit():
            n = int(s)

            if n == number:
                print('You got it!')
                break
            elif n < number:
                print('Too low!')
                score += 1
            else:
                print('Too high!')
                score += 1
        else:
            print(f'{s} is not numeric; try again!')

    print(f'Your score is {score}')

# %%
guessing_game()
# Out:
# Guess the number: 50
# Too high!
# Guess the number: 25
# Too high!
# Guess the number: 12
# Too high!
# Guess the number: 7
# Too high!
# Guess the number: 3
# Too low!
# Guess the number: 5
# Too high!
# Guess the number: 4
# You got it!
# Your score is 6

# %%
import random

def guessing_game(low_number=0, high_number=100):

    score = 0
    number = random.randint(low_number, high_number)

    while True:
        s = input('Guess the number: ').strip()

        if s.isdigit():
            n = int(s)

            if n == number:
                print('You got it!')
                break
            elif n < number:
                print('Too low!')
                score += 1
            else:
                print('Too high!')
                score += 1
        else:
            print(f'{s} is not numeric; try again!')

    print(f'Your score is {score}')

# %%
guessing_game(10, 15)
# Out:
# Guess the number: 13
# Too low!
# Guess the number: 14
# Too low!
# Guess the number: 15
# You got it!
# Your score is 2

# %% [markdown]
# # Next up:
#
# - What is `import`?
# - What happens when we import a module?

# %%
# start with a score of 100, and go down as you guess

import random

def guessing_game(low_number=0, high_number=100):

    score = 100
    number = random.randint(low_number, high_number)

    while score >= 0:
        s = input('Guess the number: ').strip()

        if s.isdigit():
            n = int(s)

            if n == number:
                print('You got it!')
                break
            elif n < number:
                print('Too low!')
                score -= 1
            else:
                print('Too high!')
                score -= 1
        else:
            print(f'{s} is not numeric; try again!')

    print(f'Your score is {score}')    

    if score == 0:
        print('You ran out of guesses!')

# %%
guessing_game(0, 100)
# Out:
# Guess the number: 50
# Too high!
# Guess the number: 30
# Too high!
# Guess the number: 25
# Too high!
# Guess the number: 15
# Too high!
# Guess the number: 10
# Too low!
# Guess the number: 13
# Too high!
# Guess the number: 12
# Too high!

# %% [markdown]
# # `import`
#
# What happens when we `import` a module?
#
# First, let's consider what happens when we `def` a function:
# - Python creates a new function object
# - Python assigns that function to our function variable.
#
# When we `import` a module, Python does two things:
#
# - Python creates a module object
# - Python assigns that module object to our variable.
#
# In other words, `import` is creating a new variable.
#
# What does it mean to "create a module object"... we'll talk about that in a bit.

# %%
def hello(name):
    return f'Hello, {name}!'

# %%
type(hello)
# Out:
# function

# %%
import os

# %%
type(os)
# Out:
# module

# %%
# how can we know what names are defined on a module?
# we can use the built-in "dir" function
# this returns the list of attributes that a module has defined
# (what are attributes? things that come after a dot!)

dir(os)
# Out:
# ['CLD_CONTINUED',
#  'CLD_DUMPED',
#  'CLD_EXITED',
#  'CLD_KILLED',
#  'CLD_STOPPED',
#  'CLD_TRAPPED',
#  'DirEntry',
#  'EX_CANTCREAT',
#  'EX_CONFIG',
#  'EX_DATAERR',
#  'EX_IOERR',
#  'EX_NOHOST',
#  'EX_NOINPUT',
#  'EX_NOPERM',
#  'EX_NOUSER',
#  'EX_OK',
#  'EX_OSERR',
#  'EX_OSFILE',
#  'EX_PROTOCOL',
#  'EX_SOFTWARE',
#  'EX_TEMPFAIL',
#  'EX_UNAVAILABLE',
#  'EX_USAGE',
#  'F_LOCK',
#  'F_OK',
#  'F_TEST',
#  'F_TLOCK',
#  'F_ULOCK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'NGROUPS_MAX',
#  'O_ACCMODE',
#  'O_APPEND',
#  'O_ASYNC',
#  'O_CLOEXEC',
#  'O_CREAT',
#  'O_DIRECTORY',
#  'O_DSYNC',
#  'O_EXCL',
#  'O_EXLOCK',
#  'O_NDELAY',
#  'O_NOCTTY',
#  'O_NOFOLLOW',
#  'O_NONBLOCK',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SHLOCK',
#  'O_SYNC',
#  'O_TRUNC',
#  'O_WRONLY',
#  'POSIX_SPAWN_CLOSE',
#  'POSIX_SPAWN_DUP2',
#  'POSIX_SPAWN_OPEN',
#  'PRIO_PGRP',
#  'PRIO_PROCESS',
#  'PRIO_USER',
#  'P_ALL',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_PGID',
#  'P_PID',
# ...

# %%
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_floor',
#  '_inst',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
# for something a bit nicer, you can always say:
help(random)
# Out:
# Help on module random:
#
# NAME
#     random - Random variable generators.
#
# DESCRIPTION
#         bytes
#         -----
#                uniform bytes (values between 0 and 255)
#
#         integers
#         --------
#                uniform within range
#
#         sequences
#         ---------
#                pick random element
#                pick random sample
#                pick weighted random sample
#                generate random permutation
#
#         distributions on the real line:
#         ------------------------------
#                uniform
#                triangular
#                normal (Gaussian)
#                lognormal
#                negative exponential
#                gamma
#                beta
#                pareto
#                Weibull
#
#         distributions on the circle (angles 0 to 2pi)
#         ---------------------------------------------
#                circular uniform
#                von Mises
#
# ...

# %% [markdown]
# # What's with the `_`?
#
# These are conventions in Python, not rules, but they're pretty standard:
#
# - Just `_` is used as a temporary variable that you don't care about
# - A name that starts with `_`, as in `_password`, is considered private, and others shouldn't touch it.
# - A name that starts with `__`, as in `__firstname`, is often part of an object, and you shouldn't really touch it, either.
# - A name that has `__` at both the start and the end is called "dunder," for "double underscore." So for example, `__init__` is pronounced "dunder init," and is for internal Python things.
# - Finally, in some data science areas, `_` at the end, such as `coef_` (coefficients) means that these are values that were calculated when the model was being trained.

# %%
import os   # I'm not specifying a filename!  I'm specifying a variable to define!

# %% [markdown]
# # How does Python find the file for the module?
#
# When we `import` the module `wxyz`, Python looks for a file called `wxyz.py`.  Where does it look?  One by one, in each of the directories defined in `sys.path`.  That's a list of strings, describing directories + zipfiles.
#
# The first location to have a matching file wins, and is loaded.

# %%
import sys    # Python language runtime
sys.path
# Out:
# ["/Users/reuven/Courses/Current/O'Reilly-2021-q3-first-steps",
#  '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python39.zip',
#  '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9',
#  '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/lib-dynload',
#  '',
#  '/Users/reuven/Library/Python/3.9/lib/python/site-packages',
#  '/usr/local/lib/python3.9/site-packages',
#  '/usr/local/lib/python3.9/site-packages/rich-10.1.0-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/utilmy-0.1.16183346-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/eventlet-0.30.1-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/qrcode-6.1-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/urllib3-1.24.2-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/SQLAlchemy-1.3.22-py3.9-macosx-11-x86_64.egg',
#  '/usr/local/lib/python3.9/site-packages/requests-2.21.0-py3.9.egg',
# ...

# %%
import asdfafasfd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-555bf2509f1c> in <module>
# ----> 1 import asdfafasfd
#
# ModuleNotFoundError: No module named 'asdfafasfd'

# %%
# what if I'm generating lots of random integers?
# Do I have to say "random.randint" each time?

# Yes... and no.

# %%
# this tells Python:
# - get the "random" variable
# - ask the object it's referring to (the "random" module) if it has a "randint" attribute
# - it does? We want to execute it with ()
# - we go and do that, passing it 0, 100

random.randint(0, 100)
# Out:
# 32

# %%
# if I'm using randint a lot, I won't want to have to say "random.randint"

randint(0, 100)  # will this work?  NO IT WILL NOT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e86d2b37b98b> in <module>
#       1 # if I'm using randint a lot, I won't want to have to say "random.randint"
#       2
# ----> 3 randint(0, 100)  # will this work?  NO IT WILL NOT
#
# NameError: name 'randint' is not defined

# %%
# we can fix this -- we can import random, and then define "randint" as as global variable

from random import randint

# %%
randint(0, 100)
# Out:
# 53

# %%
# from .. import means:
# - load the module as usual
# - it does *not* define the module as a variable in the current namespace
# - it *does* define the "import X" variable in the current namespace

from collections import Counter

# %%
# is collections defined?
collections
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-60758a3ab45b> in <module>
#       1 # is collections defined?
# ----> 2 collections
#
# NameError: name 'collections' is not defined

# %%
# is Counter defined?
Counter
# Out:
# collections.Counter

# %%
# this means:
# - find random, and load it but *don't* define it as a variable
# - it has attributes, such as randint
# - define the variable "randint" to refer to random.randint

from random import randint

# %%
# variations

import random as r    # load the "random" module, but define the variable "r"

# %%
# in the data science world, everyone says

import numpy as np
import pandas as pd

# %%
# I can also say:

from random import randint as ri

# %%
ri(3, 10)
# Out:
# 10

# %% [markdown]
# # The worst variation
#
# ```python
# from MODULE import *    # all names in MODULE should be define as variable in our namespace
# ```
#
# I **BEG** you never to use this.
#
# Several problems:
#
# - Practical problem: You have a *ton* of new global variables, and you don't even know what they're called. So you can accidentally step on them with your own variables.
# - Philosophical problem: A major part of modules is to give us separate namespaces. Here, you're saying, "I don't care about namespaces!"

# %%
# how does Python know if we've already imported a module?
# it checks in the dict sys.modules

# the keys are strings, with the module names
# the values are the modules themselves

# so... to unimportant a module

# (1) delete the module variable.  But this doesn't really unimport it
# (2) delete the key-value pair from sys.modules.

# %%
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module 'importlib._bootstrap' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  '_io': <module 'io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'posix': <module 'posix' (built-in)>,
#  '_frozen_importlib_external': <module 'importlib._bootstrap_external' (frozen)>,
#  'time': <module 'time' (built-in)>,
#  'zipimport': <module 'zipimport' (frozen)>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'codecs': <module 'codecs' from '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/codecs.py'>,
#  'encodings.aliases': <module 'encodings.aliases' from '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/encodings/aliases.py'>,
# ...

# %%
len(sys.modules)  # how many modules are currently loaded?
# Out:
# 1220

# %%
from random import randint

# %%
randint(0, 100)
# Out:
# 44

# %% [markdown]
# # Exercise: `Counter`
#
# 1. Remember that `Counter` works like a dict, but when you create it you can pass an iterable (e.g., a string, or list of strings).  The elements of the iterable are counted.
# 2. Ask the user to enter a sentence.
# 3. Use `Counter` to count how many times each character appears in that sentence.
# 4. First, load the `collections` module and use `Counter` via that name.
# 5. Then use "from.. import" to load it directly, and try that way.

# %%
import collections

s = input('Enter a string: ').strip()

c = collections.Counter(s)    # count how many times each character appears in s
print(c)
# Out:
# Enter a string: this is a test
# Counter({'t': 3, 's': 3, ' ': 3, 'i': 2, 'h': 1, 'a': 1, 'e': 1})

# %%
from collections import Counter

s = input('Enter a string: ').strip()

c = Counter(s)    # count how many times each character appears in s
print(c)
# Out:
# Enter a string: this is a test
# Counter({'t': 3, 's': 3, ' ': 3, 'i': 2, 'h': 1, 'a': 1, 'e': 1})

# %%
for key, value in c.items():
    print(f'{key}: {value}')
# Out:
# t: 3
# h: 1
# i: 2
# s: 3
#  : 3
# a: 1
# e: 1

# %%
c.most_common()
# Out:
# [('t', 3), ('s', 3), (' ', 3), ('i', 2), ('h', 1), ('a', 1), ('e', 1)]

# %%
c.most_common(4)
# Out:
# [('t', 3), ('s', 3), (' ', 3), ('i', 2)]

# %% [markdown]
# # Next up
#
# - Writing our own modules
# - What happens when our module is loaded?
# - The special `__name__` variable

# %%
import mymod

# %%
type(mymod)
# Out:
# module

# %%
# how can I know what names are defined in my module?  Use "dir"!
dir(mymod)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__']

# %%
mymod.__file__
# Out:
# "/Users/reuven/Courses/Current/O'Reilly-2021-q3-first-steps/mymod.py"

# %%
mymod.__name__
# Out:
# 'mymod'

# %%
import sys
sys.path
# Out:
# ["/Users/reuven/Courses/Current/O'Reilly-2021-q3-first-steps",
#  '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python39.zip',
#  '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9',
#  '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/lib-dynload',
#  '',
#  '/Users/reuven/Library/Python/3.9/lib/python/site-packages',
#  '/usr/local/lib/python3.9/site-packages',
#  '/usr/local/lib/python3.9/site-packages/rich-10.1.0-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/utilmy-0.1.16183346-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/eventlet-0.30.1-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/qrcode-6.1-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/urllib3-1.24.2-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/SQLAlchemy-1.3.22-py3.9-macosx-11-x86_64.egg',
#  '/usr/local/lib/python3.9/site-packages/requests-2.21.0-py3.9.egg',
# ...

# %%
# now that we've defined things in the module, let's load it up!

import mymod    # it only loads a module *ONCE* in the life of each Python program

# %%
dir(mymod)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__']

# %%
import importlib          # load up the "import" utility package
importlib.reload(mymod)   # reload the "mymod" module from disk
# Out:
# <module 'mymod' from "/Users/reuven/Courses/Current/O'Reilly-2021-q3-first-steps/mymod.py">

# %%
dir(mymod)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'hello',
#  'x',
#  'y']

# %%
# how can I use the items defined in mymod?
# same as before...

mymod.x
# Out:
# 100

# %%
mymod.y
# Out:
# [10, 20, 30]

# %%
mymod.hello('world')
# Out:
# 'Hello from mymod, world!'

# %%
globals()  # returns a dict of all global variables
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '5',
#   "def hello(name):\n    return f'Hello, {name}!'",
#   'type(hello)',
#   'import os',
#   'type(os)',
#   '# how can we know what names are defined on a module?\n# we can use the built-in "dir" function\n# this returns the list of attributes that a module has defined\n# (what are attributes? things that come after a dot!)\n\ndir(os)',
#   'dir(random)',
#   'import random\ndir(random)',
#   '# for something a bit nicer, you can always say:\nhelp(random)',
#   "import os   # I'm not specifying a filename!  I'm specifying a variable to define!",
#   'import sys    # Python language runtime\nsys.path',
#   'import asdfafasfd',
# ...

# %%
importlib.reload(mymod)
help(mymod)
# Out:
# Help on module mymod:
#
# NAME
#     mymod - This is the first line of the mymod.py docstring.
#
# DESCRIPTION
#     This is the end of the mymod.py docstring.
#     No, it isn't!
#
# FUNCTIONS
#     hello(name)
#         Greets a user with a friendly string
#
# DATA
#     x = 100
#     y = [10, 20, 30]
#
# FILE
#     /Users/reuven/Courses/Current/O'Reilly-2021-q3-first-steps/mymod.py

# %% [markdown]
# # Exercise: count_vowels
#
# 1. Create a module, `vowels.py`.  It will contain a single function, `count_vowels`. The function takes a filename, and returns the number of vowels (a, e, i, o, and u) that it finds in that file.
# 2. Import that module, and then call it, giving it a filename on your system.

# %%
import vowels

# %%
vowels
# Out:
# <module 'vowels' from "/Users/reuven/Courses/Current/O'Reilly-2021-q3-first-steps/vowels.py">

# %%
vowels.count_vowels('/etc/passwd')
# Out:
# 1845

# %%
importlib.reload(mymod)
# Out:
# Hello from mymod!
# Goodbye from mymod!
# <module 'mymod' from "/Users/reuven/Courses/Current/O'Reilly-2021-q3-first-steps/mymod.py">

# %%
mymod.__name__
# Out:
# 'mymod'

# %%
importlib.reload(mymod)
# Out:
# Hello from mymod!
# Goodbye from mymod!
# <module 'mymod' from "/Users/reuven/Courses/Current/O'Reilly-2021-q3-first-steps/mymod.py">

# %% [markdown]
# # The special `__name__` variable
#
# `__name__` is a variable that is always defined in Python. It always contains a string.
#
# If we check `__name__` inside of a module, and then we `import` that module, the name will be the same name as the module. So `str.__name__` will be `str`, and `mymod.__name__` will be `mymod`.
#
# *BUT* when we run a program standalone, its value of `__name__` is the string `__main__`.
#
# This gives us a way for the module to know whether it's being run within an import or from the command line.  Why would we want to know this?  Because we can use `if`.  We can thus distinguish between importing the module (into another program) or running the module as a standalone program.

# %%
importlib.reload(mymod)
# Out:
# <module 'mymod' from "/Users/reuven/Courses/Current/O'Reilly-2021-q3-first-steps/mymod.py">

# %% [markdown]
# # How can we use `__name__`?
#
# 1. When we run a module, it can run its own tests.
# 2. We can have an interactive part of a module, to run the functions in the module.
# 3. Sometimes, for working with multi-process programs, you need to use this as well.
#
# What is *NOT*?  It's *NOT* the same as the `main` function in C.

# %%
random
# Out:
# <module 'random' from '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/random.py'>

# %%
collections
# Out:
# <module 'collections' from '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/collections/__init__.py'>

# %%
# run the pwd magic command to find out where you should be putting your modules

# %pwd
# Out:
# "/Users/reuven/Courses/Current/O'Reilly-2021-q3-first-steps"

# %% [markdown]
# # Exercise: `count_vowels`, part 2
#
# 1. Take the existing module, `vowels.py`, and make sure it has a `count_vowels` function in it.  (You can just copy what I did from the previous exercise.)
# 2. Modify the module, such that it has an `if __name__` line.
# 3. If the program is running interactively (i.e., if `__name__` is set to be `__main__`), then ask the user to enter a filename, and pass it to `count_vowels`.
# 4. If the program is *not* running interactively, then you can just load up the functions.  No interactions.

# %%
importlib.reload(vowels)
# Out:
# <module 'vowels' from "/Users/reuven/Courses/Current/O'Reilly-2021-q3-first-steps/vowels.py">

# %%
vowels.count_vowels('/etc/passwd')
# Out:
# 1845

# %% [markdown]
# # Next up
#
# 1. Packages (briefly)
# 2. PyPI
# 3. `pip` and installing modules/packages from the Internet
# 4. What next?

# %%
sys.path
# Out:
# ["/Users/reuven/Courses/Current/O'Reilly-2021-q3-first-steps",
#  '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python39.zip',
#  '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9',
#  '/usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/lib-dynload',
#  '',
#  '/Users/reuven/Library/Python/3.9/lib/python/site-packages',
#  '/usr/local/lib/python3.9/site-packages',
#  '/usr/local/lib/python3.9/site-packages/rich-10.1.0-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/utilmy-0.1.16183346-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/eventlet-0.30.1-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/qrcode-6.1-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/urllib3-1.24.2-py3.9.egg',
#  '/usr/local/lib/python3.9/site-packages/SQLAlchemy-1.3.22-py3.9-macosx-11-x86_64.egg',
#  '/usr/local/lib/python3.9/site-packages/requests-2.21.0-py3.9.egg',
# ...

# %% [markdown]
# # Exercise: Read the `python.org` site
#
# 1. From PyPI, install `requests` -- one of the most popular packages out there, which implements an HTTP client. (That is, it's a Web browser inside of Python!)
# 2. Write a short program that:
#     - imports `requests`
#     - Uses `requests.get` (a function) to retrieve `https://python.org`.  (Just pass the URL to `requests.get` as an argument.
#     - The return value will be a "response" object.  Stick that into a variable called `r`.
#     - Finally, print the length of `r.content`.

# %%
import requests

# %%
r = requests.get('https://python.org/')

# %%
type(r)
# Out:
# requests.models.Response

# %%
len(r.content)
# Out:
# 49757
